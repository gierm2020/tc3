# %% [markdown]
# # Generador TC3

# %%
stFileIni = """
(* @NESTEDCOMMENTS := 'Yes' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
PROGRAM MAIN
VAR
	ACaName		:STRING;
	ACHwOutput	:BOOL;
	ACaUiValue		:BOOL;
	ACaUiColor		:DWORD;
	ACaUiTop		:REAL;
	ACaUiLeft		:REAL;
	ACaUiBotom	:REAL;
	ACaUIRight		:REAL;
	ACaUiVisible	:REAL;
END_VAR
(* @END_DECLARATION := '0' *)

END_PROGRAM

(* @PATH := '' *)

VISUALISATION fms205visu _VISU_TYPES : 1,1
_BG_BMP : ''
""";

stText="""
_TEXT : {0}
_PAINTZOOM : 100
"""

stSimple="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stTitulo="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16512,0,16777215,0,16777215
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : 'MS Sans Serif'
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stEtiqueta="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 4,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stActuador="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8421631,0,255,255,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stSensor="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8454016,0,32768,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stFuncion="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16776960,0,8421376,255,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stBoton="""
_BUTTON : ''
_POS : {0},{1},{2},{3},{4},{5}
_THRESH : '','','',''
_INPUT : 0
_DSP : '','{6}',''
_ZOOM : ''
_TEXT : 5,4294967283,400,0,116,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0,157
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @BUTTONCOLORS := '_COLORS : 13158600,0,14474460,0,0' *)
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @GRADIENT_AND_FRAME := '_GRADIENT_AND_FRAME: 0,0,0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
(* @NO_FRAME_AROUND_BITMAP := '_NO_FRAME_AROUND_BITMAP: 0' *)
"""

stEnd="""

_KEYINFOLIST : 0
END_VISUALISATION

(* @NESTEDCOMMENTS := 'Yes' *)
(* @GLOBAL_VARIABLE_LIST := 'Global_Variables' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
VAR_GLOBAL
END_VAR

(* @OBJECT_END := 'Global_Variables' *)
(* @CONNECTIONS := Global_Variables
FILENAME : ''
FILETIME : 0
EXPORT : 0
NUMOFCONNECTIONS : 0
*)

(* @NESTEDCOMMENTS := 'Yes' *)
(* @GLOBAL_VARIABLE_LIST := 'Variable_Configuration' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
VAR_CONFIG
END_VAR

(* @OBJECT_END := 'Variable_Configuration' *)
(* @CONNECTIONS := Variable_Configuration
FILENAME : ''
FILETIME : 0
EXPORT : 0
NUMOFCONNECTIONS : 0
*)


_ALARMCONFIG
_ALARMCONFIGNEXTTEXTID : 10002
_ALARMCONFIGFORMATS : 'HH$':$'mm$':$'ss','dd$'-$'MM$'-$'yyyy'
_ALARMCLASSLIST : 1
_ALARMCLASSID : 0
_ALARMCLASSACKTYPE : 0
_ALARMCLASSNAME : 'DEFAULT'
_ALARMCLASSDESCRIPTION : ''
_ALARMCLASSBGCOLORS : 16777215,16777215,16777215
_ALARMCLASSTEXTCOLORS : 3394560,255,16711680
_ALARMCLASSBITMAPS : '','',''
_ALARMACTIONLIST : 0
(* @ALARMCLASSRESETCOLORS := '_ALARMCLASSRESETCOLORS: 33023,16777215' *)
(* @ALARMCLASSRESETBITMAP := '_ALARMCLASSRESETBITMAP: $'$'' *)
_ALARMGROUPLISTNAME : 'System'
_ALARMGROUPPATH : 'System'
_ALARMGROUPLIST : 0
_VISUALSETTINGSFLAGS : 0,0,0,0
_VISUALSETTINGSFLAGS : '','',''
_VISUALSETTINGSDYNTEXTFILECOUNT : 0

(* @ALARMCONFIGFLAGS := '_ALARMCONFIGFLAGS: 4' *)
(* @ALARMCONFIGGLOBALDB_STR := '_ALARMCONFIGGLOBALDB_STRINGS: $'$',$'$',$'$',$'$'' *)
(* @ALARMCONFIGGLOBALDB_NUM := '_ALARMCONFIGGLOBALDB_NUMBERS: 0,0' *)
_END_ALARMCONFIG


LIBRARY
STANDARD.LIB
(* @LIBRARYSYMFILEINFO := '0' *)
NumOfPOUs: 20
CONCAT: 0
CTD: 0
CTU: 0
CTUD: 0
DELETE: 0
F_TRIG: 0
FIND: 0
INSERT: 0
LEFT: 0
LEN: 0
MID: 0
R_TRIG: 0
REPLACE: 0
RIGHT: 0
RS: 0
SEMA: 0
SR: 0
TOF: 0
TON: 0
TP: 0
NumOfGVLs: 1
'Global Variables 0': 0
END_LIBRARY

PLC_CONFIGURATION
_ELEMENT 15700
_ELEMENT_END
PLC_END


RESOURCE

TASK Standard (PRIORITY := 0, INTERVAL := T#10ms);
MAIN
{Additional_info : 0,0,4294967295,0,1,4294967295}
END_TASK

END_RESOURCE


_WORKSPACE
_GLOBALVISUALSETTINGS
_VISUALSETTINGSFLAGS : 0,0,0,0
_VISUALSETTINGSFLAGS : '','',''
_VISUALSETTINGSDYNTEXTFILECOUNT : 0
_VISUALBITMAPLISTCOUNT : 0
_END_GLOBALVISUALSETTINGS
_END_WORKSPACE
"""

# %%
lstUi =(
('Plato',	0,	0,	8,	12,	'Imagen'),
('Titulo',	0,	13,	1,	53,	'Titulo'),
('Logo',	0,	67,	5,	7,	'Imagen'),
('Requisitos',	2,	13,	1,	11,	'Titulo'),
('Resultados',	2,	25,	1,	9,	'Titulo'),
('PanelFisico',	2,	35,	1,	21,	'Titulo'),
('Velocidad',	2,	58,	1,	8,	'Titulo'),
('NoTapas',	3,	13,	1,	6,	'Etiqueta'),
('NoTapasIn',	3,	19,	1,	5,	'Input'),
('Pendientes',	3,	25,	1,	6,	'Etiqueta'),
('PendientesIn',	3,	31,	1,	3,	'Salida'),
('PE',	3,	36,	1,	2,	'Sensor'),
('POC',	3,	39,	1,	2,	'Sensor'),
('PM',	3,	42,	1,	2,	'Sensor'),
('SM',	3,	45,	1,	2,	'Sensor'),
('Umbral',	4,	13,	1,	6,	'Etiqueta'),
('UmbralIn',	4,	19,	1,	3,	'Input'),
('UmbralMm',	4,	22,	1,	2,	'Etiqueta'),
('Realizadas',	4,	25,	1,	6,	'Etiqueta'),
('RealizadasOut',	4,	31,	1,	3,	'Salida'),
('PanelImagen',	4,	35,	2,	21,	'Imagen'),
('Aluminio',	5,	13,	1,	6,	'Etiqueta'),
('ABIn',	5,	19,	1,	2,	'Sensor'),
('AAIn',	5,	22,	1,	2,	'Sensor'),
('Rechazadas',	5,	25,	1,	6,	'Etiqueta'),
('RechazadasOut',	5,	31,	1,	3,	'Salida'),
('Blanco',	6,	13,	1,	6,	'Etiqueta'),
('BBIn',	6,	19,	1,	2,	'Sensor'),
('BAIn',	6,	22,	1,	2,	'Sensor'),
('AS',	6,	36,	1,	2,	'Actuador'),
('LM',	6,	42,	1,	2,	'Actuador'),
('DPO',	6,	51,	1,	2,	'Actuador'),
('LA',	6,	54,	1,	2,	'Actuador'),
('Negro',	7,	13,	1,	6,	'Etiqueta'),
('NBIn',	7,	19,	1,	2,	'Sensor'),
('NAIn',	7,	22,	1,	2,	'Sensor'),
('Planta',	7,	58,	1,	16,	'Boton'),
('Alimentador',	8,	58,	1,	7,	'Titulo'),
('K_1',	8,	65,	1,	3,	'Actuador'),
('k1',	8,	72,	1,	2,	'Sensor'),
('Llenar',	9,	1,	1,	5,	'Boton'),
('Vaciar',	9,	7,	1,	5,	'Boton'),
('Estacion',	9,	14,	19,	42,	'Imagen'),
('Carga',	9,	58,	3,	7,	'Titulo'),
('A_1',	9,	65,	1,	3,	'Actuador'),
('a0',	9,	69,	1,	2,	'Sensor'),
('a1',	9,	72,	1,	2,	'Sensor'),
('B_1',	10,	65,	1,	3,	'Actuador'),
('b0',	10,	69,	1,	2,	'Sensor'),
('b1',	10,	72,	1,	2,	'Sensor'),
('Empezar',	11,	1,	1,	5,	'Boton'),
('Emerg',	11,	7,	1,	5,	'Boton'),
('C_1',	11,	65,	1,	3,	'Actuador'),
('Medidor',	12,	58,	1,	7,	'Titulo'),
('L_1',	12,	65,	1,	3,	'Actuador'),
('dh',	12,	69,	1,	5,	'Sensor'),
('Pausar',	13,	1,	1,	5,	'Boton'),
('Reset',	13,	7,	1,	5,	'Boton'),
('Fotoelectrico',	13,	58,	1,	7,	'Titulo'),
('df',	13,	69,	1,	3,	'Sensor'),
('Inductivo',	14,	58,	1,	7,	'Titulo'),
('di',	14,	69,	1,	3,	'Sensor'),
('Funcion',	15,	1,	1,	11,	'Boton'),
('Evacuador',	15,	58,	1,	7,	'Titulo'),
('F_0',	15,	65,	1,	3,	'Actuador'),
('f0',	15,	69,	1,	2,	'Sensor'),
('Alimentar',	16,	1,	1,	5,	'Funcion'),
('FM',	16,	7,	1,	5,	'Actuador'),
('F_1',	16,	65,	1,	3,	'Actuador'),
('f1',	16,	72,	1,	2,	'Sensor'),
('Cargar',	17,	1,	1,	5,	'Funcion'),
('G_1',	17,	65,	1,	3,	'Actuador'),
('g0',	17,	69,	1,	2,	'Sensor'),
('MedirAlt',	18,	1,	1,	5,	'Funcion'),
('AlturaOut',	18,	7,	1,	3,	'Salida'),
('AlturaMm',	18,	10,	1,	2,	'Etiqueta'),
('V_1',	18,	65,	1,	3,	'Actuador'),
('v1',	18,	72,	1,	2,	'Sensor'),
('DetColor',	19,	1,	1,	5,	'Funcion'),
('ColorOut',	19,	7,	1,	5,	'Salida'),
('Descarga',	19,	58,	3,	7,	'Titulo'),
('H_1',	19,	65,	1,	3,	'Actuador'),
('h0',	19,	69,	1,	2,	'Sensor'),
('h1',	19,	72,	1,	2,	'Sensor'),
('DetMaterial',	20,	1,	1,	5,	'Funcion'),
('MaterialOut',	20,	7,	1,	5,	'Salida'),
('I_1',	20,	65,	1,	3,	'Actuador'),
('i0',	20,	69,	1,	2,	'Sensor'),
('i1',	20,	72,	1,	2,	'Sensor'),
('Rechazar',	21,	1,	1,	5,	'Funcion'),
('J_1',	21,	65,	1,	3,	'Actuador'),
('Descargar',	22,	1,	1,	5,	'Funcion'),
('Plato',	22,	58,	2,	7,	'Titulo'),
('D_1',	22,	65,	1,	3,	'Actuador'),
('d0',	22,	69,	1,	2,	'Sensor'),
('Girar',	23,	1,	1,	5,	'Funcion'),
('E_1',	23,	65,	1,	3,	'Actuador'),
('Situar',	24,	1,	1,	5,	'Funcion'),
('Avanza',	24,	7,	1,	5,	'Actuador'),
('Cinta',	24,	58,	4,	7,	'Titulo'),
('RUN',	24,	65,	1,	3,	'Actuador'),
('pp',	24,	69,	1,	2,	'Sensor'),
('Transferir',	25,	1,	1,	5,	'Funcion'),
('Retrocede',	25,	7,	1,	5,	'Actuador'),
('REV',	25,	65,	1,	3,	'Actuador'),
('cp0',	25,	69,	1,	2,	'Sensor'),
('R_1',	26,	65,	1,	3,	'Actuador'),
('cp1',	26,	69,	1,	2,	'Sensor'),
('Ejecutar',	27,	1,	1,	5,	'Boton'),
('Continuar',	27,	7,	1,	5,	'Boton'),
('S_1',	27,	65,	1,	3,	'Actuador'),
('cp2',	27,	69,	1,	2,	'Sensor'),
('Modo',	28,	1,	1,	3,	'Etiqueta'),
('ModoOut',	28,	4,	1,	2,	'Salida'),
('ModoDesc',	28,	7,	1,	15,	'Salida'),
('MensajesOut',	28,	26,	1,	48,	'Salida'))

# %%
len(lstUi)
# Out:
# 116

# %%
iInput = 0
stOut = stFileIni + stText.format(len(lstUi)) 
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Titulo':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-1
        dx = lstUi[i][4]*20-1
        stOut+=stTitulo.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Etiqueta':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-1
        dx = lstUi[i][4]*20-1
        stOut+=stEtiqueta.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Actuador':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-1
        dx = lstUi[i][4]*20-1
        stOut+=stActuador.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Sensor':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-1
        dx = lstUi[i][4]*20-1
        stOut+=stSensor.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Funcion':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-1
        dx = lstUi[i][4]*20-1
        stOut+=stFuncion.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Boton':
        y = lstUi[i][1]*30-6
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-6+3
        dx = lstUi[i][4]*20-1
        stOut+=stBoton.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    else:
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-1
        dx = lstUi[i][4]*20-1
        stOut+=stSimple.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
stOut+=stEnd

# %%
stOut
# Out:
# "\n(* @NESTEDCOMMENTS := 'Yes' *)\n(* @PATH := '' *)\n(* @OBJECTFLAGS := '0, 8' *)\n(* @SYMFILEFLAGS := '2048' *)\nPROGRAM MAIN\nVAR\n\tACaName\t\t:STRING;\n\tACHwOutput\t:BOOL;\n\tACaUiValue\t\t:BOOL;\n\tACaUiColor\t\t:DWORD;\n\tACaUiTop\t\t:REAL;\n\tACaUiLeft\t\t:REAL;\n\tACaUiBotom\t:REAL;\n\tACaUIRight\t\t:REAL;\n\tACaUiVisible\t:REAL;\nEND_VAR\n(* @END_DECLARATION := '0' *)\n\nEND_PROGRAM\n\n(* @PATH := '' *)\n\nVISUALISATION fms205visu _VISU_TYPES : 1,1\n_BG_BMP : ''\n\n_TEXT : 116\n_PAINTZOOM : 100\n\n_SIMPLE : 0\n_LINEWIDTH : 0\n_NOCOLORS : 1,1\n_POS : 0,0,239,239,0,0\n_COLORS : 16777215,0,16777215,0,0\n_VARIABLES : '','','','','','','',''\n_THRESH : '','','',''\n_DSP : '','Plato',''\n_ZOOM : ''\n_INPUT : 0\n_TEXT : 5,4294967283,400,0,0,0,0,0\n_FONT : ''\n_EXEC : ''\n_TEXTVARIABLES : '','','','',''\n_COLORVARIABLES : '','','','','',''\n_ACCESSLEVELS : 2,2,2,2,2,2,2,2\n_OBJECT : 0,0\n_THRESH2 : '','','',''\n_INPUTTYPE : '','',''\n_HIDDENINPUT : 0\n_END_ELEM\n(* @TEXTSCALINGVAR
# ...

# %%
f = open("../../tc2/o1proyecto/lab/lab17/tc3.exp", "w")
f.write(stOut)
f.close()
