# %% [markdown]
# # Generador TC3

# %%
stFBIni = """
(* @NESTEDCOMMENTS := 'Yes' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
FUNCTION_BLOCK FB_FMS205_UI
VAR_INPUT
END_VAR
VAR_OUTPUT
END_VAR
VAR
"""

stFBVars = """
"""

stFileIni = """

END_VAR
(* @END_DECLARATION := '0' *)
;

END_FUNCTION_BLOCK


(* @NESTEDCOMMENTS := 'Yes' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
PROGRAM MAIN
VAR
	ui	: FB_FMS205_UI;
END_VAR
(* @END_DECLARATION := '0' *)
;
END_PROGRAM

(* @PATH := '' *)

VISUALISATION fms205visu _VISU_TYPES : 1,1
_BG_BMP : ''
""";

stText="""
_TEXT : {0}
_PAINTZOOM : 100
"""

stSimple="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stTitulo="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16512,0,16777215,0,16777215
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : 'MS Sans Serif'
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stEtiqueta="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 4,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stSalida="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 12632256,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stActuadorSin="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8421631,0,255,255,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stActuador="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8421631,0,255,255,0
_VARIABLES : '','','','','','','',''
_THRESH : '','MAIN.ui.act_{6}','MAIN.ui.act_{6}',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 65536
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stSensor="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8454016,0,32768,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','MAIN.ui.sen_{6}','MAIN.ui.sen_{6}',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 65536
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stFuncion="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16776960,0,8421376,255,0
_VARIABLES : '','','','','','','',''
_THRESH : '','MAIN.ui.fun_{6}','MAIN.ui.fun_{6}',''
_DSP : '','{6}',''
_ZOOM : ''
_INPUT : 65536
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stBoton="""
_BUTTON : ''
_POS : {0},{1},{2},{3},{4},{5}
_THRESH : '','','',''
_INPUT : 0
_DSP : '','{6}',''
_ZOOM : ''
_TEXT : 5,4294967283,400,0,116,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0,157
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @BUTTONCOLORS := '_COLORS : 13158600,0,14474460,0,0' *)
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @GRADIENT_AND_FRAME := '_GRADIENT_AND_FRAME: 0,0,0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
(* @NO_FRAME_AROUND_BITMAP := '_NO_FRAME_AROUND_BITMAP: 0' *)
"""

stEnd="""

_KEYINFOLIST : 0
END_VISUALISATION

(* @NESTEDCOMMENTS := 'Yes' *)
(* @GLOBAL_VARIABLE_LIST := 'Global_Variables' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
VAR_GLOBAL
END_VAR

(* @OBJECT_END := 'Global_Variables' *)
(* @CONNECTIONS := Global_Variables
FILENAME : ''
FILETIME : 0
EXPORT : 0
NUMOFCONNECTIONS : 0
*)

(* @NESTEDCOMMENTS := 'Yes' *)
(* @GLOBAL_VARIABLE_LIST := 'Variable_Configuration' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
VAR_CONFIG
END_VAR

(* @OBJECT_END := 'Variable_Configuration' *)
(* @CONNECTIONS := Variable_Configuration
FILENAME : ''
FILETIME : 0
EXPORT : 0
NUMOFCONNECTIONS : 0
*)


_ALARMCONFIG
_ALARMCONFIGNEXTTEXTID : 10002
_ALARMCONFIGFORMATS : 'HH$':$'mm$':$'ss','dd$'-$'MM$'-$'yyyy'
_ALARMCLASSLIST : 1
_ALARMCLASSID : 0
_ALARMCLASSACKTYPE : 0
_ALARMCLASSNAME : 'DEFAULT'
_ALARMCLASSDESCRIPTION : ''
_ALARMCLASSBGCOLORS : 16777215,16777215,16777215
_ALARMCLASSTEXTCOLORS : 3394560,255,16711680
_ALARMCLASSBITMAPS : '','',''
_ALARMACTIONLIST : 0
(* @ALARMCLASSRESETCOLORS := '_ALARMCLASSRESETCOLORS: 33023,16777215' *)
(* @ALARMCLASSRESETBITMAP := '_ALARMCLASSRESETBITMAP: $'$'' *)
_ALARMGROUPLISTNAME : 'System'
_ALARMGROUPPATH : 'System'
_ALARMGROUPLIST : 0
_VISUALSETTINGSFLAGS : 0,0,0,0
_VISUALSETTINGSFLAGS : '','',''
_VISUALSETTINGSDYNTEXTFILECOUNT : 0

(* @ALARMCONFIGFLAGS := '_ALARMCONFIGFLAGS: 4' *)
(* @ALARMCONFIGGLOBALDB_STR := '_ALARMCONFIGGLOBALDB_STRINGS: $'$',$'$',$'$',$'$'' *)
(* @ALARMCONFIGGLOBALDB_NUM := '_ALARMCONFIGGLOBALDB_NUMBERS: 0,0' *)
_END_ALARMCONFIG


LIBRARY
STANDARD.LIB
(* @LIBRARYSYMFILEINFO := '0' *)
NumOfPOUs: 20
CONCAT: 0
CTD: 0
CTU: 0
CTUD: 0
DELETE: 0
F_TRIG: 0
FIND: 0
INSERT: 0
LEFT: 0
LEN: 0
MID: 0
R_TRIG: 0
REPLACE: 0
RIGHT: 0
RS: 0
SEMA: 0
SR: 0
TOF: 0
TON: 0
TP: 0
NumOfGVLs: 1
'Global Variables 0': 0
END_LIBRARY

PLC_CONFIGURATION
_ELEMENT 15700
_ELEMENT_END
PLC_END


RESOURCE

TASK Standard (PRIORITY := 0, INTERVAL := T#10ms);
MAIN
{Additional_info : 0,0,4294967295,0,1,4294967295}
END_TASK

END_RESOURCE


_WORKSPACE
_GLOBALVISUALSETTINGS
_VISUALSETTINGSFLAGS : 0,0,0,0
_VISUALSETTINGSFLAGS : '','',''
_VISUALSETTINGSDYNTEXTFILECOUNT : 0
_VISUALBITMAPLISTCOUNT : 0
_END_GLOBALVISUALSETTINGS
_END_WORKSPACE
"""

# %%
lstUi =(
    
('Plato',	0,	0,	8,	12,	'Imagen'),
('FMS205 - Estación de carga de tapas',	0,	13,	1.8,	43,	'Titulo'),
('Logo',	0,	67,	4,	7,	'Imagen'),
('Requisitos',	2,	13,	1,	12,	'Titulo'),
('Resultados',	2,	26,	1,	8,	'Titulo'),
('Panel Físico',	2,	35,	1,	21,	'Titulo'),
    
('Velocidad',	0,	58,	4,	8,	'Imagen'),
('Número de Tapas',	3,	13,	1,	6,	'Etiqueta'),
('NoTapasIn',	3,	19,	1,	3,	'Input'),
('Pendientes',	3,	26,	1,	5,	'Etiqueta'),
('PendientesIn',	3,	31,	1,	3,	'Salida'),
('PE',	3,	36,	1,	2,	'Sensor'),
('POC',	3,	39,	1,	2,	'Sensor'),
('PM',	3,	42,	1,	2,	'Sensor'),
('SM',	3,	45,	1,	2,	'Sensor'),
    
('Umbral Alta/Baja',	4,	13,	1,	6,	'Etiqueta'),
('UmbralIn',	4,	19,	1,	3,	'Input'),
(' mm',	4,	22,	1,	2,	'Etiqueta'),
('Realizadas',	4,	26,	1,	5,	'Etiqueta'),
('RealizadasOut',	4,	31,	1,	3,	'Salida'),
('PanelImagen',	4,	35,	2,	21,	'Imagen'),
    
('Aceptar Aluminio',	5,	13,	1,	6,	'Etiqueta'),
('ABIn',	5,	19,	1,	3,	'Sensor'),
('AAIn',	5,	22,	1,	3,	'Sensor'),
('Rechazadas',	5,	26,	1,	5,	'Etiqueta'),
('RechazadasOut',	5,	31,	1,	3,	'Salida'),
    
('Aceptar Blancas',	6,	13,	1,	6,	'Etiqueta'),
('BBIn',	6,	19,	1,	3,	'Sensor'),
('BAIn',	6,	22,	1,	3,	'Sensor'),
('AS',	6,	36,	1,	2,	'Actuador'),
('LM',	6,	42,	1,	2,	'Actuador'),
('DPO',	6,	51,	1,	2,	'Actuador'),
('LA',	6,	54,	1,	2,	'Actuador'),
    
('Aceptar Negras',	7,	13,	1,	6,	'Etiqueta'),
('NBIn',	7,	19,	1,	3,	'Sensor'),
('NAIn',	7,	22,	1,	3,	'Sensor'),
('Planta',	5,	58,	1,	16,	'Boton'),
    
('Alimentador',	6,	58,	1,	7,	'Titulo'),
('K_1',	6,	65,	1,	3,	'Actuador'),
('k1',	6,	71,	1,	3,	'Sensor'),
('Llenar',	9,	1,	1,	5,	'Boton'),
('Vaciar',	9,	7,	1,	5,	'Boton'),
    
('Estacion',	9,	14,	17,	42,	'Imagen'),
('Carga',	7,	58,	3,	7,	'Titulo'),
('A_1',	7,	65,	1,	3,	'Actuador'),
('a0',	7,	68,	1,	3,	'Sensor'),
('a1',	7,	71,	1,	3,	'Sensor'),
    
('B_1',	8,	65,	1,	3,	'Actuador'),
('b0',	8,	68,	1,	3,	'Sensor'),
('b1',	8,	71,	1,	3,	'Sensor'),
    
('Empezar',	10.5,	1,	1,	5,	'Boton'),
('Emerg',	10.5,	7,	1,	5,	'Boton'),
    
('C_1',	9,	65,	1,	3,	'Actuador'),
    
('Medidor',	10,	58,	1,	7,	'Titulo'),
('L_1',	10,	65,	1,	3,	'Actuador'),
('dh',	10,	68,	1,	6,	'Sensor'),
    
('Pausar',	12,	1,	1,	5,	'Boton'),
('Reset',	12,	7,	1,	5,	'Boton'),
('Fotoelectrico',	11,	58,	1,	7,	'Titulo'),
('df',	11,	68,	1,	3,	'Sensor'),
('Inductivo',	12,	58,	1,	7,	'Titulo'),
('di',	12,	68,	1,	3,	'Sensor'),
    
('Funcion',	13.5,	1,	1,	11,	'Boton'),
('Evacuador',	13,	58,	4,	7,	'Titulo'),
('F_0',	13,	65,	1,	3,	'Actuador'),
('f0',	13,	68,	1,	3,	'Sensor'),
('Alimentar',	15,	1,	1,	5,	'Funcion'),
('FM',	15,	7,	1,	5,	'Actuador'),
('F_1',	14,	65,	1,	3,	'Actuador'),
('f1',	14,	71,	1,	3,	'Sensor'),
('Cargar',	16,	1,	1,	5,	'Funcion'),
('G_1',	15,	65,	1,	3,	'Actuador'),
('g0',	15,	68,	1,	3,	'Sensor'),
('MedAltura',	17,	1,	1,	5,	'Funcion'),
('AlturaOut',	17,	7,	1,	3,	'Salida'),
(' mm',	17,	10,	1,	2,	'Etiqueta'),
    
('V_1',	16,	65,	1,	3,	'Actuador'),
('v1',	16,	71,	1,	3,	'Sensor'),
('DetColor',	18,	1,	1,	5,	'Funcion'),
('ColorOut',	18,	7,	1,	5,	'Salida'),
('Descarga',	17,	58,	3,	7,	'Titulo'),
('H_1',	17,	65,	1,	3,	'Actuador'),
('h0',	17,	68,	1,	3,	'Sensor'),
('h1',	17,	71,	1,	3,	'Sensor'),
('DetMaterial',	19,	1,	1,	5,	'Funcion'),
('MaterialOut',	19,	7,	1,	5,	'Salida'),
('I_1',	18,	65,	1,	3,	'Actuador'),
('i0',	18,	68,	1,	3,	'Sensor'),
('i1',	18,	71,	1,	3,	'Sensor'),
('Rechazar',	20,	1,	1,	5,	'Funcion'),
('J_1',	19,	65,	1,	3,	'Actuador'),
('Descargar',	21,	1,	1,	5,	'Funcion'),
('Plato',	20,	58,	2,	7,	'Titulo'),
('D_1',	20,	65,	1,	3,	'Actuador'),
('d0',	20,	68,	1,	3,	'Sensor'),
('Girar',	22,	1,	1,	5,	'Funcion'),
('E_1',	21,	65,	1,	3,	'Actuador'),
('Situar',	23,	1,	1,	5,	'Funcion'),
('Avanza',	23,	7,	1,	5,	'Actuador'),
('Cinta',	22,	58,	4,	7,	'Titulo'),
('RUN',	22,	65,	1,	3,	'Actuador'),
('pp',	22,	68,	1,	3,	'Sensor'),
('Transferir',	24,	1,	1,	5,	'Funcion'),
('Retrocede',	24,	7,	1,	5,	'Actuador'),
('REV',	23,	65,	1,	3,	'Actuador'),
('cp0',	23,	68,	1,	3,	'Sensor'),
('R_1',	24,	65,	1,	3,	'Actuador'),
('cp1',	24,	68,	1,	3,	'Sensor'),
('Ejecutar',	25.5,	1,	1,	5,	'Boton'),
('Continuar',	25.5,	7,	1,	5,	'Boton'),
('S_1',	25,	65,	1,	3,	'Actuador'),
('cp2',	25,	68,	1,	3,	'Sensor'),

('MensajesOut',	26.5,	1,	1,	55,	'Etiqueta'),
('Modo',	26.5,	58,	1,	2,	'Etiqueta'),
('ModoOut',	26.5,	60,	1,	2,	'Salida'),
 ('ModoDesc',	26.5,	62,	1,	12,	'Salida'))

# %%
len(lstUi)
# Out:
# 116

# %%
iInput = 0
stOut = stFBIni
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Actuador':
        stOut += "    act_{}		: BOOL;\n".format(lstUi[i][0])
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Sensor':
        stOut += "    sen_{}		: BOOL;\n".format(lstUi[i][0])
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Funcion':
        stOut += "    fun_{}		: BOOL;\n".format(lstUi[i][0])
    
stOut +=stFBVars+stFileIni + stText.format(len(lstUi)) 
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Titulo':
        y = int(lstUi[i][1]*30)
        x = int(lstUi[i][2]*20)
        dy = int(lstUi[i][3]*30-2)
        dx = int(lstUi[i][4]*20-2)
        stOut+=stTitulo.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Etiqueta':
        y = int(lstUi[i][1]*30)
        x = int(lstUi[i][2]*20)
        dy = int(lstUi[i][3]*30-2)
        dx = int(lstUi[i][4]*20-2)
        stOut+=stEtiqueta.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Salida':
        y = int(lstUi[i][1]*30)
        x = int(lstUi[i][2]*20)
        dy = int(lstUi[i][3]*30-2)
        dx = int(lstUi[i][4]*20-2)
        stOut+=stSalida.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Actuador':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-2
        dx = lstUi[i][4]*20-2
        stOut+=stActuador.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Sensor':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-2
        dx = lstUi[i][4]*20-2
        stOut+=stSensor.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Funcion':
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-2
        dx = lstUi[i][4]*20-2
        stOut+=stFuncion.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    elif lstUi[i][5] == 'Boton':
        y = int(lstUi[i][1]*30-10)
        x = int(lstUi[i][2]*20)
        dy = int(lstUi[i][3]*30-8+5)
        dx = int(lstUi[i][4]*20-2)
        stOut+=stBoton.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
    else:
        y = lstUi[i][1]*30
        x = lstUi[i][2]*20
        dy = lstUi[i][3]*30-2
        dx = lstUi[i][4]*20-2
        stOut+=stSimple.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput)
stOut+=stEnd

# %%
stOut
# Out:
# "\n(* @NESTEDCOMMENTS := 'Yes' *)\n(* @PATH := '' *)\n(* @OBJECTFLAGS := '0, 8' *)\n(* @SYMFILEFLAGS := '2048' *)\nFUNCTION_BLOCK FB_FMS205_UI\nVAR_INPUT\nEND_VAR\nVAR_OUTPUT\nEND_VAR\nVAR\n    act_AS\t\t: BOOL;\n    act_LM\t\t: BOOL;\n    act_DPO\t\t: BOOL;\n    act_LA\t\t: BOOL;\n    act_K_1\t\t: BOOL;\n    act_A_1\t\t: BOOL;\n    act_B_1\t\t: BOOL;\n    act_C_1\t\t: BOOL;\n    act_L_1\t\t: BOOL;\n    act_F_0\t\t: BOOL;\n    act_FM\t\t: BOOL;\n    act_F_1\t\t: BOOL;\n    act_G_1\t\t: BOOL;\n    act_V_1\t\t: BOOL;\n    act_H_1\t\t: BOOL;\n    act_I_1\t\t: BOOL;\n    act_J_1\t\t: BOOL;\n    act_D_1\t\t: BOOL;\n    act_E_1\t\t: BOOL;\n    act_Avanza\t\t: BOOL;\n    act_RUN\t\t: BOOL;\n    act_Retrocede\t\t: BOOL;\n    act_REV\t\t: BOOL;\n    act_R_1\t\t: BOOL;\n    act_S_1\t\t: BOOL;\n    sen_PE\t\t: BOOL;\n    sen_POC\t\t: BOOL;\n    sen_PM\t\t: BOOL;\n    sen_SM\t\t: BOOL;\n    sen_ABIn\t\t: BOOL;\n    sen_AAIn\t\t: BOOL;\n    sen_BBIn\t\t: BOOL;\n    sen_BAIn\t\t: BOOL;\n    sen_NBIn\t\t: BOOL;\n    sen_NAIn\t\t: BOOL;\n    sen_k1\t\t: BOOL;\n    sen_a0\t\t: BOOL;\n    sen_a1\t\t: BOOL;\n    sen_b0\t\t: BOOL;\n    sen_b1\t\t: BOOL;\n    sen_dh\t\t: BOOL;\n    sen_df\t\t: BOOL;\n    sen_di\t\t: BOOL;\n    sen_f0\t\t: BOOL;\n    sen_f1\t\t: BOOL;\n    sen_g0\t\t: BOOL;\n    sen_v1\t\t: BOOL;\n    sen_h0\t\t: BOOL;\n    sen_h1\t\t: BOOL;\n    sen_i0\t\t: BOOL;\n    sen_i1\t\t: BOOL;\n    sen_d0\t\t: BOOL;\n    sen_pp\t\t: BOOL;\n    sen_cp0\t\t: BOOL;\n    sen_cp1\t\t: BOOL;\n    sen_cp2\t\t: BOOL;\n    fun_Alimentar\t\t: BOOL;\n    fun_Cargar\t\t: BOOL;\n    fun_MedAltura\t\t: BOOL;\n    fun_DetColor\t\t: BOOL;\n    fun_DetMaterial\t\t: BOOL;\n    fun_Rechazar\t\t: BOOL;\n    fun_Descargar\t\t: BOOL;\n    fun_Girar\t\t: BOOL;\n    fun_Situar\t\t: BOOL;\n    fun_Transferir\t\t: BOOL;\n\n\n\nEND_VAR\n(* @END_DECLARATION := '0' *)\n;\n\nEND_FUNCTION_BLOCK\n\n\n(* @NESTEDCOMMENTS := 'Yes' *)\n(* @PATH := '' *)\n(* @OBJECTFLAGS := '0, 8' *)\n(* @SYMFILEFLAGS := '2048' *)\nPROGRAM MAIN\nVAR\n\tui\t: FB_FMS205_UI;\nEND_VAR\n(* @END_DECLARATION := '0' *)\n;\nEND_PROGRAM\n\n(* @PATH := '' *)\n\nVISUALISATION fms205visu _VISU_TYPES : 1,1\n_BG_BMP : ''\n\n_TEXT : 116\n_PAINTZOOM : 100\n\n_SIMPLE : 0\n_LINEWIDTH : 0\n_NOCOLORS : 1,1\n_POS : 0,0,238,238,0,0\n_COLORS : 16777215,0,16777215,0,0\n_VARIABLES : '','','','','','','',''\n_THRESH : '','','',''\n_DSP : '','Plato',''\n_ZOOM : ''\n_INPUT : 0\n_TEXT : 5,4294967283,400,0,0,0,0,0\n_FONT : ''\n_EXEC : ''\n_TEXTVARIABLES : '','','','',''\n_COLORVARIABLES : '','','','','',''\n_ACCESSLEVELS : 2,2,2,2,2,2,2,2\n_OBJECT : 0,0\n_THRESH2 : '','','',''\n_INPUTTYPE : '','',''\n_HIDDENINPUT : 0\n_END_ELEM\n(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)\n(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)\n(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)\n\n_SIMPLE : 0\n_LINEWIDTH : 0\n_NOCOLORS : 0,1\n_POS : 260,0,1118,52,260,0\n_COLORS : 16512,0,16777215,0,16777215\n_VARIABLES : '','','','','','','',''\n_THRESH : '','','',''\n_DSP : '','FMS205 - Estación de carga de tapas',''\n_ZOOM : ''\n_INPUT : 0\n_TEXT : 5,4294967283,400,0,0,0,0,0\n_FONT : 'MS Sans Serif'\n_EXEC : ''\n_TEXTVARIABLES : '','','','',''\n_COLORVARIABLES : '','','','','',''\n_ACCESSLEVELS : 2,2,2,2,2,2,2,2\n_OBJECT : 0,0\n_THRESH2 : '','','',''\n_INPUTTYPE : '','',''\n_HIDDENINPUT : 0\n_END_ELEM\n(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)\n(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)\n(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)\n\n_SIMPLE : 0\n_LINEWIDTH : 0\n_NOCOLORS : 1,1\n_POS : 1340,0,1478,118,1340,0\n_COLORS : 16777215,0,16777215,0,0\n_VARIABLES : '','','','','','','',''\n_THRESH : '','','',''\n_DSP : '','Logo',''\n_ZOOM : ''\n_INPUT : 0\n_TEXT : 5,4294967283,400,0,0,0,0,0\n_FONT : ''\n_EXEC : ''\n_TEXTVARIABLES : '','','','',''\n_COLORVARIABLES : '','','','','',''\n_ACCESSLEVELS : 2,2,2,2,2,2,2,2\n_OBJECT : 0,0\n_THRESH2 : '','','',''\n_INPUTTYPE : '','',''\n_HIDDENINPUT : 0\n_END_ELEM\n(* @TEXTSCALINGVARS := '_TEXTSCAL ...

# %%
f = open("../../tc2/o1proyecto/lab/lab17/tc3b.exp", "w")
f.write(stOut)
f.close()
