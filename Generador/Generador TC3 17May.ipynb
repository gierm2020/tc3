# %% [markdown]
# # Generador TC3

# %%
stFBIni = """
(* @NESTEDCOMMENTS := 'Yes' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
FUNCTION_BLOCK FB_FMS205_UI
VAR_INPUT
    angulo: REAL;
END_VAR
VAR_OUTPUT
END_VAR
VAR
"""

stFBVars = """
"""

stFileIni = """

END_VAR
(* @END_DECLARATION := '0' *)
;

END_FUNCTION_BLOCK


(* @NESTEDCOMMENTS := 'Yes' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
PROGRAM MAIN
VAR
	ui	: FB_FMS205_UI;
END_VAR
(* @END_DECLARATION := '0' *)

ui.angulo := ui.angulo+0.1;

END_PROGRAM

(* @PATH := '' *)

VISUALISATION fms205visu _VISU_TYPES : 1,1
_BG_BMP : ''
""";

stText="""
_TEXT : {0}
_PAINTZOOM : 100
"""

stSimple="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stTitulo="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8388608,0,16777215,0,16777215
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : 'MS Sans Serif'
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stEtiqueta="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 4,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stSalida="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 12632256,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stActuadorSin="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8421631,0,255,255,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""
stActuador="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 16744703,0,8388863,8388863,0
_VARIABLES : '','','','','','','',''
_THRESH : '','MAIN.ui.act_{6}','MAIN.ui.act_{6}',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 65536
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : 'NOT MAIN.ui.bot_Planta','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stSensor="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 8454016,0,65280,65280,0
_VARIABLES : '','','','','','','',''
_THRESH : '','MAIN.ui.sen_{6}','MAIN.ui.sen_{6}',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 65536
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : 'NOT MAIN.ui.bot_Planta','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stFuncion="""
_SIMPLE : 0
_LINEWIDTH : 0
_NOCOLORS : 0,1
_POS : {0},{1},{2},{3},{4},{5}
_COLORS : 4210816,0,16384,16384,16777215
_VARIABLES : '','','','','','','',''
_THRESH : '','MAIN.ui.fun_{6}','MAIN.ui.fun_{6}',''
_DSP : '','{8}',''
_ZOOM : ''
_INPUT : 65536
_TEXT : 5,4294967283,400,{7},0,0,0,0
_FONT : 'MS Sans Serif'
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
"""

stBoton="""
_BUTTON : ''
_POS : {0},{1},{2},{3},{4},{5}
_THRESH : '','','MAIN.ui.bot_{9}',''
_INPUT : 65536
_DSP : '','{8}',''
_ZOOM : ''
_TEXT : 5,4294967283,400,0,116,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0,157
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @BUTTONCOLORS := '_COLORS : 13158600,0,14474460,0,0' *)
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @GRADIENT_AND_FRAME := '_GRADIENT_AND_FRAME: 0,0,0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)
(* @NO_FRAME_AROUND_BITMAP := '_NO_FRAME_AROUND_BITMAP: 0' *)
"""

stEnd="""
_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 20,20,221,221,125,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','',''
_THRESH : '','','',''
_DSP : '','',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,118,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 170,100,211,141,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','0º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 149,149,190,190,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','45º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 100,170,141,211,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','90º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 51,149,92,190,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','135º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 30,100,71,141,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','180º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 51,51,92,92,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','225º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 100,30,141,71,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','270º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_SIMPLE : 2
_LINEWIDTH : 0
_NOCOLORS : 1,1
_POS : 149,51,190,92,120,120
_COLORS : 16777215,0,16777215,0,0
_VARIABLES : '','','','','','','','MAIN.ui.angulo'
_THRESH : '','','',''
_DSP : '','315º',''
_ZOOM : ''
_INPUT : 0
_TEXT : 5,4294967283,400,0,121,0,0,0
_FONT : ''
_EXEC : ''
_TEXTVARIABLES : '','','','',''
_COLORVARIABLES : '','','','','',''
_ACCESSLEVELS : 2,2,2,2,2,2,2,2
_OBJECT : 0,0
_THRESH2 : '','','',''
_INPUTTYPE : '','',''
_HIDDENINPUT : 0
_END_ELEM
(* @TEXTSCALINGVARS := '_TEXTSCALINGVARS: $'$',$'$'' *)
(* @EXTENDEDSIMPLESHAPE := '_SIMPLE: 0' *)
(* @INPUTTAPFALSE := '_INPUTTAPFALSE: 0' *)

_KEYINFOLIST : 0
END_VISUALISATION

(* @NESTEDCOMMENTS := 'Yes' *)
(* @GLOBAL_VARIABLE_LIST := 'Global_Variables' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
VAR_GLOBAL
END_VAR

(* @OBJECT_END := 'Global_Variables' *)
(* @CONNECTIONS := Global_Variables
FILENAME : ''
FILETIME : 0
EXPORT : 0
NUMOFCONNECTIONS : 0
*)

(* @NESTEDCOMMENTS := 'Yes' *)
(* @GLOBAL_VARIABLE_LIST := 'Variable_Configuration' *)
(* @PATH := '' *)
(* @OBJECTFLAGS := '0, 8' *)
(* @SYMFILEFLAGS := '2048' *)
VAR_CONFIG
END_VAR

(* @OBJECT_END := 'Variable_Configuration' *)
(* @CONNECTIONS := Variable_Configuration
FILENAME : ''
FILETIME : 0
EXPORT : 0
NUMOFCONNECTIONS : 0
*)


_ALARMCONFIG
_ALARMCONFIGNEXTTEXTID : 10002
_ALARMCONFIGFORMATS : 'HH$':$'mm$':$'ss','dd$'-$'MM$'-$'yyyy'
_ALARMCLASSLIST : 1
_ALARMCLASSID : 0
_ALARMCLASSACKTYPE : 0
_ALARMCLASSNAME : 'DEFAULT'
_ALARMCLASSDESCRIPTION : ''
_ALARMCLASSBGCOLORS : 16777215,16777215,16777215
_ALARMCLASSTEXTCOLORS : 3394560,255,16711680
_ALARMCLASSBITMAPS : '','',''
_ALARMACTIONLIST : 0
(* @ALARMCLASSRESETCOLORS := '_ALARMCLASSRESETCOLORS: 33023,16777215' *)
(* @ALARMCLASSRESETBITMAP := '_ALARMCLASSRESETBITMAP: $'$'' *)
_ALARMGROUPLISTNAME : 'System'
_ALARMGROUPPATH : 'System'
_ALARMGROUPLIST : 0
_VISUALSETTINGSFLAGS : 0,0,0,0
_VISUALSETTINGSFLAGS : '','',''
_VISUALSETTINGSDYNTEXTFILECOUNT : 0

(* @ALARMCONFIGFLAGS := '_ALARMCONFIGFLAGS: 4' *)
(* @ALARMCONFIGGLOBALDB_STR := '_ALARMCONFIGGLOBALDB_STRINGS: $'$',$'$',$'$',$'$'' *)
(* @ALARMCONFIGGLOBALDB_NUM := '_ALARMCONFIGGLOBALDB_NUMBERS: 0,0' *)
_END_ALARMCONFIG


LIBRARY
STANDARD.LIB
(* @LIBRARYSYMFILEINFO := '0' *)
NumOfPOUs: 20
CONCAT: 0
CTD: 0
CTU: 0
CTUD: 0
DELETE: 0
F_TRIG: 0
FIND: 0
INSERT: 0
LEFT: 0
LEN: 0
MID: 0
R_TRIG: 0
REPLACE: 0
RIGHT: 0
RS: 0
SEMA: 0
SR: 0
TOF: 0
TON: 0
TP: 0
NumOfGVLs: 1
'Global Variables 0': 0
END_LIBRARY

PLC_CONFIGURATION
_ELEMENT 15700
_ELEMENT_END
PLC_END


RESOURCE

TASK Standard (PRIORITY := 0, INTERVAL := T#10ms);
MAIN
{Additional_info : 0,0,4294967295,0,1,4294967295}
END_TASK

END_RESOURCE


_WORKSPACE
_GLOBALVISUALSETTINGS
_VISUALSETTINGSFLAGS : 0,0,0,0
_VISUALSETTINGSFLAGS : '','',''
_VISUALSETTINGSDYNTEXTFILECOUNT : 0
_VISUALBITMAPLISTCOUNT : 0
_END_GLOBALVISUALSETTINGS
_END_WORKSPACE
"""

# %%
lstUi =(
    
('Plato',	0,	0,	8,	12,	'Imagen',	'Plato'),
('Titulo',	0,	13,	1.8,	43,	'Titulo','FMS205 - Estación de carga de tapas'),
('Velocidad',	0,	58,	4,	8,	'Imagen',	'Velocidad'),
('Logo',	0,	67,	4,	7,	'Imagen',	'Logo'),
('Requisitos',	2,	13,	1,	12,	'Titulo',	'Requisitos de producción'),
('Resultados',	2,	26,	1,	8,	'Titulo',	'Resultados'),
('PanelFisico',	2,	35,	1,	21,	'Titulo',	'Panel Físico'),
('NoTapas',	3,	13,	1,	8,	'Etiqueta',	'Número de tapas'),
('NoTapasIn',	3,	19,	1,	3,	'Input',	'NoTapasIn'),
('Pendientes',	3,	26,	1,	5,	'Etiqueta',	'Pendientes'),
('PendientesIn',	3,	31,	1,	3,	'Salida',	'PendientesIn'),
('PE',	3,	36,	1,	2,	'Sensor',	'PE'),
('POC',	3,	39,	1,	2,	'Sensor',	'POC'),
('PM',	3,	42,	1,	2,	'Sensor',	'PM'),
('SM',	3,	45,	1,	2,	'Sensor',	'SM'),
('Umbral',	4,	13,	1,	6,	'Etiqueta',	'Umbral Alta/Baja'),
('UmbralIn',	4,	19,	1,	3,	'Input',	'UmbralIn'),
('UmbralMm',	4,	22,	1,	2,	'Etiqueta',	' mm'),
('Realizadas',	4,	26,	1,	6,	'Etiqueta',	'Realizadas'),
('RealizadasOut',	4,	31,	1,	3,	'Salida',	'RealizadasOut'),
('PanelImagen',	4,	35,	2,	21,	'Imagen',	'PanelImagen'),
('Aluminio',	5,	13,	1,	6,	'Etiqueta',	'Aceptar aluminio'),
('ABIn',	5,	19,	1,	3,	'Funcion',	'Alu. Baja'),
('AAIn',	5,	22,	1,	3,	'Funcion',	'Alu. Alta'),
('Rechazadas',	5,	26,	1,	6,	'Etiqueta',	'Rechazadas'),
('RechazadasOut',	5,	31,	1,	3,	'Salida',	'RechazadasOut'),
('Planta',	5,	58,	1,	16,	'Boton',	'Planta (F4)'),
('Blanco',	6,	13,	1,	6,	'Etiqueta',	'Aceptar blancas'),
('BBIn',	6,	19,	1,	3,	'Funcion',	'Bln. Baja'),
('BAIn',	6,	22,	1,	3,	'Funcion',	'Bln. Alta'),
('Alimentador',	6,	58,	1,	7,	'Titulo',	'Alimentador'),
('K_1',	6,	65,	1,	3,	'Actuador',	'K_1'),
('FM',	6,	68,	1,	3,	'Actuador',	'FM'),
('k1',	6,	71,	1,	3,	'Sensor',	'k1'),
('AS',	6,	36,	1,	2,	'Actuador',	'AS'),
('LM',	6,	42,	1,	2,	'Actuador',	'LM'),
('DPO',	6,	51,	1,	2,	'Actuador',	'DPO'),
('LA',	6,	54,	1,	2,	'Actuador',	'LA'),
('Negro',	7,	13,	1,	6,	'Etiqueta',	'Aceptar negras'),
('NBIn',	7,	19,	1,	3,	'Funcion',	'Ngr. Baja'),
('NAIn',	7,	22,	1,	3,	'Funcion',	'Ngr. Alta'),
('Carga',	7,	58,	3,	7,	'Titulo',	'Carga'),
('A_1',	7,	65,	1,	3,	'Actuador',	'A_1'),
('a0',	7,	68,	1,	3,	'Sensor',	'a0'),
('a1',	7,	71,	1,	3,	'Sensor',	'a1'),
('B_1',	8,	65,	1,	3,	'Actuador',	'B_1'),
('b0',	8,	68,	1,	3,	'Sensor',	'b0'),
('b1',	8,	71,	1,	3,	'Sensor',	'b1'),
('Estacion',	9,	14,	17,	42,	'Imagen',	'Estacion'),

('Empezar',	9,	0,	1,	12,	'Boton', 'Empezar (F1)'),
('Llenar',	10,	1,	1,	5,	'Funcion',	'Llenar (F2)'),
('Vaciar',	10,	6,	1,	5,	'Funcion',	'Vaciar (F3)'),

('Emerg',	11.5,	0,	1,	12,	'Boton', 'Emergencia (D1)'),
('Pausar',	12.7,	0,	1,	5,	'Boton',	'Pausar (A3->4)'),
('Reset',	12.7,	7,	1,	5,	'Boton',	'Reset (A6->1)'),

('C_1',	9,	65,	1,	3,	'Actuador',	'C_1'),
('Medidor',	10,	58,	1,	7,	'Titulo',	'Medidor'),
('L_1',	10,	65,	1,	3,	'Actuador',	'L_1'),
('dh',	10,	68,	1,	6,	'Sensor',	'dh'),
('Fotoelectrico',	11,	58,	1,	7,	'Titulo',	'Det. Fotoeléctrico'),
('df',	11,	68,	1,	3,	'Sensor',	'df'),
    
('Inductivo',	12,	58,	1,	7,	'Titulo',	'Det. Inductivo'),
('di',	12,	68,	1,	3,	'Sensor',	'di'),
('Evacuador',	13,	58,	4,	7,	'Titulo',	'Evacuador'),
('F_0',	13,	65,	1,	3,	'Actuador',	'F_0'),
('f0',	13,	68,	1,	3,	'Sensor',	'f0'),
('Funcion',	14,	0,	1,	12,	'Boton','Función (F5)'),
('F_1',	14,	65,	1,	3,	'Actuador',	'F_1'),
('f1',	14,	71,	1,	3,	'Sensor',	'f1'),
    
('Alimentar',	15,	0,	1,	4,	'Funcion',	'Alimentar'),
('Girar',	15,	4,	1,	4,	'Funcion',	'Girar'),
('Situar',	15,	8,	1,	4,	'Funcion',	'Situar'),

('Altura',	17,	0,	1,	4,	'Funcion',	'Medir Altura'),
('Color',	17,	4,	1,	4,	'Funcion',	'DetColor'),
('Material',	17,	8,	1,	4,	'Funcion',	'DetMaterial'),

('AlturaOut',	18,	0,	1,	3,	'Salida',	'AlturaOut'),
('AlturaMm',	18,	3,	1,	1,	'Etiqueta',	' mm'),
('ColorOut',	18,	4,	1,	4,	'Salida',	'ColorOut'),
('MaterialOut',	18,	8,	1,	4,	'Salida',	'MaterialOut'),

('Cargar',	20,	0,	1,	4,	'Funcion',	'Cargar'),
('Rechazar',	20,	4,	1,	4,	'Funcion',	'Rechazar'),
('Descargar',	20,	8,	1,	4,	'Funcion',	'Descargar'),
('Transferir',	21,	8,	1,	4,	'Funcion',	'Transferir'),
('Ejecutar',	22.5,	1,	1,	4,	'Boton',	'Ejecutar'),
('Continuar',	22.5,	7,	1,	4,	'Boton',	'Continuar'),

('G_1',	15,	65,	1,	3,	'Actuador',	'G_1'),
('g0',	15,	68,	1,	3,	'Sensor',	'g0'),
('V_1',	16,	65,	1,	3,	'Actuador',	'V_1'),
('v1',	16,	71,	1,	3,	'Sensor',	'v1'),
('Descarga',	17,	58,	3,	7,	'Titulo',	'Descarga'),
('H_1',	17,	65,	1,	3,	'Actuador',	'H_1'),
('h0',	17,	68,	1,	3,	'Sensor',	'h0'),
('h1',	17,	71,	1,	3,	'Sensor',	'h1'),
('I_1',	18,	65,	1,	3,	'Actuador',	'I_1'),
('i0',	18,	68,	1,	3,	'Sensor',	'i0'),
('i1',	18,	71,	1,	3,	'Sensor',	'i1'),
('J_1',	19,	65,	1,	3,	'Actuador',	'J_1'),
('Plato',	20,	58,	2,	7,	'Titulo',	'Plato'),
('D_1',	20,	65,	1,	3,	'Actuador',	'D_1'),
('d0',	20,	68,	1,	3,	'Sensor',	'd0'),
('E_1',	21,	65,	1,	3,	'Actuador',	'E_1'),
('Cinta',	22,	58,	4,	7,	'Titulo',	'Cinta'),
('RUN',	22,	65,	1,	3,	'Actuador',	'RUN'),
('pp',	22,	68,	1,	3,	'Sensor',	'pp'),
('Avanza',	22,	71,	1,	3,	'Actuador',	'Avanza'),
('REV',	23,	65,	1,	3,	'Actuador',	'REV'),
('cp0',	23,	68,	1,	3,	'Sensor',	'cp0'),
('Retroc',	23,	71,	1,	3,	'Actuador',	'Retroc.'),
('R_1',	24,	65,	1,	3,	'Actuador',	'R_1'),
('cp1',	24,	68,	1,	3,	'Sensor',	'cp1'),
('S_1',	25,	65,	1,	3,	'Actuador',	'S_1'),
('cp2',	25,	68,	1,	3,	'Sensor',	'cp2'),
('MensajesOut',	26.5,	0,	1,	56,	'Etiqueta',	'MensajesOut'),
('Modo',	26.5,	58,	1,	2,	'Etiqueta', 'Modo'),
('ModoOut',	26.5,	60,	1,	2,	'Salida','Fx'),
('ModoDesc',	26.5,	62,	1,	12,	'Salida',	'Descripción modo'))

# %%
iInput = 0
stOut = stFBIni
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Actuador':
        stOut += "    act_{}		: BOOL;\n".format(lstUi[i][0])
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Sensor':
        stOut += "    sen_{}		: BOOL;\n".format(lstUi[i][0])
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Funcion':
        stOut += "    fun_{}		: BOOL;\n".format(lstUi[i][0])
for i in range(len(lstUi)):
    if lstUi[i][5] == 'Boton':
        stOut += "    bot_{}		: BOOL;\n".format(lstUi[i][0])
    
stOut +=stFBVars+stFileIni + stText.format(len(lstUi)) 
for i in range(len(lstUi)):
    # print(i)
    y = int(lstUi[i][1]*30)+2
    x = int(lstUi[i][2]*20)+10
    dy = int(lstUi[i][3]*30-2)
    dx = int(lstUi[i][4]*20-2)
    if lstUi[i][5] == 'Titulo':
        stOut+=stTitulo.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    elif lstUi[i][5] == 'Etiqueta':
        stOut+=stEtiqueta.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    elif lstUi[i][5] == 'Salida':
        stOut+=stSalida.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    elif lstUi[i][5] == 'Actuador':
        stOut+=stActuador.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    elif lstUi[i][5] == 'Sensor':
        stOut+=stSensor.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    elif lstUi[i][5] == 'Funcion':
        stOut+=stFuncion.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    elif lstUi[i][5] == 'Boton':
        y = int(lstUi[i][1]*30-10)+2
        x = int(lstUi[i][2]*20)+10
        dy = int(lstUi[i][3]*30-8+5)
        dx = int(lstUi[i][4]*20-2)
        stOut+=stBoton.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
    else:
        stOut+=stSimple.format(x,y,x+dx,y+dy,x,y,lstUi[i][0], iInput, lstUi[i][6], lstUi[i][0])
stOut+=stEnd

# %%
print(stOut)
# Out:
# (* @NESTEDCOMMENTS := 'Yes' *)
# (* @PATH := '' *)
# (* @OBJECTFLAGS := '0, 8' *)
# (* @SYMFILEFLAGS := '2048' *)
# FUNCTION_BLOCK FB_FMS205_UI
# VAR_INPUT
#     angulo: REAL;
# END_VAR
# VAR_OUTPUT
# END_VAR
# VAR
#     act_K_1		: BOOL;
#     act_FM		: BOOL;
#     act_AS		: BOOL;
#     act_LM		: BOOL;
#     act_DPO		: BOOL;
#     act_LA		: BOOL;
#     act_A_1		: BOOL;
#     act_B_1		: BOOL;
#     act_C_1		: BOOL;
#     act_L_1		: BOOL;
#     act_F_0		: BOOL;
#     act_F_1		: BOOL;
#     act_G_1		: BOOL;
#     act_V_1		: BOOL;
#     act_H_1		: BOOL;
#     act_I_1		: BOOL;
#     act_J_1		: BOOL;
#     act_D_1		: BOOL;
#     act_E_1		: BOOL;
#     act_RUN		: BOOL;
#     act_Avanza		: BOOL;
#     act_REV		: BOOL;
#     act_Retroc		: BOOL;
#     act_R_1		: BOOL;
#     act_S_1		: BOOL;
#     sen_PE		: BOOL;
#     sen_POC		: BOOL;
#     sen_PM		: BOOL;
#     sen_SM		: BOOL;
#     sen_k1		: BOOL;
#     sen_a0		: BOOL;
#     sen_a1		: BOOL;
#     sen_b0		: BOOL;
#     sen_b1		: BOOL;
# ...

# %%
f = open("../../tc2/o1proyecto/lab/lab17/tc3c.exp", "w")
f.write(stOut)
f.close()
